# %% [markdown]
# ### 보스턴 집값 예측 딥러닝

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split

import tensorflow as tf
import pandas as pd
import numpy as np

# %%
df_ko = pd.read_csv("./dataset/housing.csv" , delim_whitespace=True, 
                    names = ["범죄 발생 수", "주거 구역 비중", "상업 비중", "찰스강 위치", 
                             "일산화질소", "방 개수", "오래된 집 비율","고용시설 까지 거리", 
                             "순환고속도로 접근", "부동산 세율", "학생 및 교사 비율", 
                             "흑인 비율", "최저급여 인구 비율","집 가격"])
df_ko
# Out:
#      범죄 발생 수  주거 구역 비중  상업 비중  찰스강 위치  일산화질소   방 개수  오래된 집 비율  고용시설 까지 거리  \
# 0    0.00632      18.0   2.31       0  0.538  6.575      65.2      4.0900
# 1    0.02731       0.0   7.07       0  0.469  6.421      78.9      4.9671
# 2    0.02729       0.0   7.07       0  0.469  7.185      61.1      4.9671
# 3    0.03237       0.0   2.18       0  0.458  6.998      45.8      6.0622
# 4    0.06905       0.0   2.18       0  0.458  7.147      54.2      6.0622
# ..       ...       ...    ...     ...    ...    ...       ...         ...
# 501  0.06263       0.0  11.93       0  0.573  6.593      69.1      2.4786
# 502  0.04527       0.0  11.93       0  0.573  6.120      76.7      2.2875
# 503  0.06076       0.0  11.93       0  0.573  6.976      91.0      2.1675
# 504  0.10959       0.0  11.93       0  0.573  6.794      89.3      2.3889
# 505  0.04741       0.0  11.93       0  0.573  6.030      80.8      2.5050
#
#      순환고속도로 접근  부동산 세율  학생 및 교사 비율   흑인 비율  최저급여 인구 비율  집 가격
# ...

# %%
dataset = df_ko.values
dataset
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 3.9690e+02, 4.9800e+00,
#         2.4000e+01],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 3.9690e+02, 9.1400e+00,
#         2.1600e+01],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 3.9283e+02, 4.0300e+00,
#         3.4700e+01],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 5.6400e+00,
#         2.3900e+01],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 3.9345e+02, 6.4800e+00,
#         2.2000e+01],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 3.9690e+02, 7.8800e+00,
#         1.1900e+01]])

# %%
X = dataset[:,:13]
Y = dataset[:, 13]

# %%
seed=0
np.random.seed(seed)
tf.random.set_seed(3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=seed)

# %%
print("len(X) : ", len(X))
print("len(X_train) : ", len(X_train))
print("len(X_test) : ", len(X_test))
print("-"*50)
print("shape(X) : ", np.shape(X))
print("shape(X_train) : ", np.shape(X_train))
print("shape(X_test) : ", np.shape(X_test))
print("-"*50)
print("len(Y) : ", len(X))
print("len(Y_train) : ", len(X_train))
print("len(Y_test) : ", len(X_test))
print("-"*50)
print("shape(Y) : ", np.shape(Y))
print("shape(Y_train) : ", np.shape(Y_train))
print("shape(Y_test) : ", np.shape(Y_test))
# Out:
# len(X) :  506
# len(X_train) :  354
# len(X_test) :  152
# --------------------------------------------------
# shape(X) :  (506, 13)
# shape(X_train) :  (354, 13)
# shape(X_test) :  (152, 13)
# --------------------------------------------------
# len(Y) :  506
# len(Y_train) :  354
# len(Y_test) :  152
# --------------------------------------------------
# shape(Y) :  (506,)
# shape(Y_train) :  (354,)
# shape(Y_test) :  (152,)

# %% [markdown]
# #### TensorBoard

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2021, 6, 25, 15, 7, 11, 741201)

# %%
datetime.now().strftime('%Y%m%d-%H%M%S')
# Out:
# '20210625-150712'

# %%
# 현재 날짜 및 시각으로 디렉토리 이름으로 로그 디렉토리 생성
logdir = "log\\" + datetime.now().strftime("%Y%m%d-%H%M%S")
logdir
# Out:
# 'log\\20210625-150716'

# %%
import os

# %%
os.getcwd()
# Out:
# 'c:\\ai\\2021_ai'

# %%
import tensorboard

# %%
tensorboard.__version__
# Out:
# '2.4.0'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
model = Sequential()
model.add(Dense(30, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(X_train, Y_train, epochs=200, batch_size=50, callbacks=[tensorboard_callback])
# Out:
# Train on 354 samples
# Epoch 1/200
# 354/354 [==============================] - 1s 4ms/sample - loss: 25765.7962 - accuracy: 0.0000e+00
# Epoch 2/200
# 354/354 [==============================] - 0s 90us/sample - loss: 15701.4255 - accuracy: 0.0000e+00
# Epoch 3/200
# 354/354 [==============================] - 0s 51us/sample - loss: 9250.2510 - accuracy: 0.0000e+00
# Epoch 4/200
# 354/354 [==============================] - 0s 68us/sample - loss: 5337.0530 - accuracy: 0.0000e+00
# Epoch 5/200
# 354/354 [==============================] - 0s 85us/sample - loss: 3047.1340 - accuracy: 0.0000e+00
# Epoch 6/200
# 354/354 [==============================] - 0s 48us/sample - loss: 1725.8540 - accuracy: 0.0000e+00
# Epoch 7/200
# 354/354 [==============================] - 0s 54us/sample - loss: 1157.4145 - accuracy: 0.0000e+00
# Epoch 8/200
# 354/354 [==============================] - 0s 124us/sample - loss: 922.8097 - accuracy: 0.0000e+00
# Epoch 9/200
# ...

# %%
# !pip3 install requests==2.21.0 && pip3 install docker-compose
# Out:
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.4
#     Uninstalling urllib3-1.26.4:
#       Successfully uninstalled urllib3-1.26.4
#   Attempting uninstall: idna
#     Found existing installation: idna 2.10
#     Uninstalling idna-2.10:
#       Successfully uninstalled idna-2.10
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# ...
#   Created wheel for dockerpty: filename=dockerpty-0.4.1-py3-none-any.whl size=16605 sha256=0807769da8a4a9a2ea0823fdcb04fa8d7b24cdbca3845cbb01cee6868a5ef002
#   Stored in directory: c:\users\user12\appdata\local\pip\cache\wheels\0b\40\ea\b275182c42dc7be184c36518d42999bc5267268af2639e409b
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=ab013027410169401e1453e82dcebd121887ad929d83eb0f69f7640f1c0ca9e3
# ...

# %%
# !pip3 install --upgrade docker-compose

# %%
# log 폴더 있는 경로>tensorboard --logdir=./log/20210605-150716/
# 크롬에서 http://localhost:6006
